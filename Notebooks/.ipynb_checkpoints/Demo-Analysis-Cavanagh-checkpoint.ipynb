# %% [markdown]
# In this notebook, we show how to use the functions in ../src/utils.py to retrieve the wavelet estimate of DDM, and produce the plots presented in the reference paper, for the Cavanagh dataset.

# %% [markdown]
# ### 0. Import the functions

# %%
import sys
sys.path.insert(1, '../src')

from utils import *

# %% [markdown]
# ### 1. Import the data

# %% [markdown]
# In this section, we import the .npz files for the observables P and DT.

# %%
P = np.load("../Data/P_observed_cavanagh.npz")
DT = np.load("../Data/DT_observed_cavanagh.npz")

# %% [markdown]
# ### 2. Retrieve $\lambda$ and u_diff using Wavelet estimator

# %% [markdown]
# In this section, we use the functions defined in the src file for retrieving the DDM parameters using wavelet estimator.

# %%
l = get_l(P)

# %%
l_til = l_tilde(l)[0]
l_til2 = l_tilde(l_til)[0]

#check consistence
l_diff = np.abs(l_til2 - l_til)
np.sum(l_diff)
# Out:
# 4.468647674116255e-15

# %%
DT_til = DT_tilde(l_til, DT)

# %%
λ, udiff = wavelet(l_til, DT_til)

print("λ : ", λ)
print("udiff : \n", udiff)
# Out:
# λ :  51.484541216487045
# udiff :
#  [[ 0.         -0.01172363 -0.0178569  -0.04364932 -0.04570818 -0.0543877 ]
#  [ 0.01172363  0.         -0.00613327 -0.03192569 -0.03398455 -0.04266407]
#  [ 0.0178569   0.00613327  0.         -0.02579242 -0.02785128 -0.0365308 ]
#  [ 0.04364932  0.03192569  0.02579242  0.         -0.00205886 -0.01073838]
#  [ 0.04570818  0.03398455  0.02785128  0.00205886  0.         -0.00867952]
#  [ 0.0543877   0.04266407  0.0365308   0.01073838  0.00867952  0.        ]]

# %% [markdown]
# ### 3. Visualization

# %% [markdown]
# In this section, we evaluate graphically how the DDM estimated through the wavelet estimator fits the data, by plotting this in contrast with the theoretical DDM.

# %%
plot_P(P, λ, udiff)

# %%
plot_DT(DT, λ, udiff)
# Out:
# /Users/renb/Desktop/projects/LtDS-DDM/Notebooks/../src/utils.py:181: RuntimeWarning: invalid value encountered in true_divide
#   return λ * np.tanh(λ * udiff / 2) / udiff
